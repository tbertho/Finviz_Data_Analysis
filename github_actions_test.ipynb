# %%
from urllib.request import Request, urlopen
from bs4 import BeautifulSoup
import requests
import pandas as pd
import datetime
import csv

path = 'C:/Users/trist/code/Data/Finviz_insider/Test/AMZN_test.csv'

root = "https://finviz.com/quote.ashx?t="
ticker = "AMZN"
date_format = "%d.%m.%Y"

url = root + ticker

def crawl(url):
    req = Request(url = url, headers={"user-agent": "my-app"})
    response = urlopen(req)

    ###
    print("Response: " + str(response))

    html = BeautifulSoup(response, 'html')
    insider_table = html.find(class_="body-table styled-table-new is-rounded p-0 mt-2")

    ###
    print("Insider Table: " + str(insider_table))

    parsed_data = []
   
    for row in insider_table.find_all("tr")[1:]:
        insider_name = row.find('td')
        # Get the Tradername in the first td element
        if insider_name is not None:
            insider_name = insider_name.text.strip()
        else:
            insider_name = None
        # Get the title of the Insider in the second td element
        insider_title = row.find_all('td')[1]
        if insider_title is not None:
            insider_title = insider_title.text.strip()
        else:
            insider_title = None
        # Get the date of the transaction in the third td element
        transaction_date = row.find_all('td')[2]
        if transaction_date is not None:
            transaction_date = transaction_date.text.strip()
        else:
            transaction_date = None
        # Get the type of transaction in the fourth td element
        transaction_type = row.find_all('td')[3]
        if transaction_type is not None:
            transaction_type = transaction_type.text.strip()
        else:
            transaction_type = None
        # Get the Cost of transaction in the fifth td element
        cost = row.find_all('td')[4]
        if cost is not None:
            cost = cost.text.strip()
        else:
            cost = None
        # Get the num of shares in the sixth td element
        num_shares = row.find_all('td')[5]
        if num_shares is not None:
            num_shares = num_shares.text.strip()
        else:
            num_shares = None
        # Get the Value of shares in the seventh td element
        value_shares = row.find_all('td')[6]
        if value_shares is not None:
            value_shares = value_shares.text.strip()
        else:
            value_shares = None
        # Get the num of shares the insider owns in the eighth td element
        total_num_shares_insider_owns = row.find_all('td')[7]
        if total_num_shares_insider_owns is not None:
            total_num_shares_insider_owns = total_num_shares_insider_owns.text.strip()
        else:
            total_num_shares_insider_owns = None
        # Get the date of the SEC Form, ka was das ist,  the ninth td element
        SEC_date = row.find_all('td')[7]
        if SEC_date is not None:
            SEC_date = SEC_date.text.strip()
        else:
            SEC_date = None

        parsed_data.append([insider_name, insider_title, transaction_date, transaction_type,
                            cost, num_shares, value_shares, total_num_shares_insider_owns, SEC_date])
    return parsed_data
    
def create_initial_df(path):

    list = crawl(url)
    df = pd.DataFrame(list, columns = ["insider" , "title", "transaction_date", "transaction_type",
                            "cost", "num_shares", "value_shares", "total_num_shares_insider_owns", "SEC_date"])
    #save df to local storage
    df.to_csv(path, index=False)

create_initial_df(path)
# Out:
# Response: <http.client.HTTPResponse object at 0x0000016B7A7472E0>
# Insider Table: None
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\trist\code\Finviz Scraper\github_actions_test.ipynb Cell 1 line 9
#      <a href='vscode-notebook-cell:/c%3A/Users/trist/code/Finviz%20Scraper/github_actions_test.ipynb#W0sZmlsZQ%3D%3D?line=95'>96</a>     #save df to local storage
#      <a href='vscode-notebook-cell:/c%3A/Users/trist/code/Finviz%20Scraper/github_actions_test.ipynb#W0sZmlsZQ%3D%3D?line=96'>97</a>     df.to_csv(path, index=False)
# ---> <a href='vscode-notebook-cell:/c%3A/Users/trist/code/Finviz%20Scraper/github_actions_test.ipynb#W0sZmlsZQ%3D%3D?line=98'>99</a> create_initial_df(path)
#
# c:\Users\trist\code\Finviz Scraper\github_actions_test.ipynb Cell 1 line 9
#      <a href='vscode-notebook-cell:/c%3A/Users/trist/code/Finviz%20Scraper/github_actions_test.ipynb#W0sZmlsZQ%3D%3D?line=90'>91</a> def create_initial_df(path):
# ---> <a href='vscode-notebook-cell:/c%3A/Users/trist/code/Finviz%20Scraper/github_actions_test.ipynb#W0sZmlsZQ%3D%3D?line=92'>93</a>     list = crawl(url)
#      <a href='vscode-notebook-cell:/c%3A/Users/trist/code/Finviz%20Scraper/github_actions_test.ipynb#W0sZmlsZQ%3D%3D?line=93'>94</a>     df = pd.DataFrame(list, columns = ["insider" , "title", "transaction_date", "transaction_type",
#      <a href='vscode-notebook-cell:/c%3A/Users/trist/code/Finviz%20Scraper/github_actions_test.ipynb#W0sZmlsZQ%3D%3D?line=94'>95</a>                             "cost", "num_shares", "value_shares", "total_num_shares_insider_owns", "SEC_date"])
#      <a href='vscode-notebook-cell:/c%3A/Users/trist/code/Finviz%20Scraper/github_actions_test.ipynb#W0sZmlsZQ%3D%3D?line=95'>96</a>     #save df to local storage
#
# c:\Users\trist\code\Finviz Scraper\github_actions_test.ipynb Cell 1 line 3
#      <a href='vscode-notebook-cell:/c%3A/Users/trist/code/Finviz%20Scraper/github_actions_test.ipynb#W0sZmlsZQ%3D%3D?line=26'>27</a> print("Insider Table: " + str(insider_table))
#      <a href='vscode-notebook-cell:/c%3A/Users/trist/code/Finviz%20Scraper/github_actions_test.ipynb#W0sZmlsZQ%3D%3D?line=28'>29</a> parsed_data = []
# ---> <a href='vscode-notebook-cell:/c%3A/Users/trist/code/Finviz%20Scraper/github_actions_test.ipynb#W0sZmlsZQ%3D%3D?line=30'>31</a> for row in insider_table.find_all("tr")[1:]:
#      <a href='vscode-notebook-cell:/c%3A/Users/trist/code/Finviz%20Scraper/github_actions_test.ipynb#W0sZmlsZQ%3D%3D?line=31'>32</a>     insider_name = row.find('td')
#      <a href='vscode-notebook-cell:/c%3A/Users/trist/code/Finviz%20Scraper/github_actions_test.ipynb#W0sZmlsZQ%3D%3D?line=32'>33</a>     # Get the Tradername in the first td element
#
# AttributeError: 'NoneType' object has no attribute 'find_all'
