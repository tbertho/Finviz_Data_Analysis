# %%
from urllib.request import Request, urlopen
from bs4 import BeautifulSoup
import requests
import pandas as pd
import datetime
import csv

path = 'C:/Users/trist/code/Data/Finviz_insider/Test/AMZN_test.csv'

root = "https://finviz.com/quote.ashx?t="
ticker = "AMZN"
date_format = "%d.%m.%Y"

url = root + ticker

def crawl(url):
    req = Request(url = url, headers={"user-agent": "my-app"})
    response = urlopen(req)

    ###
    print("Response: " + str(response))

    html = BeautifulSoup(response, 'html')
    insider_table = html.find(class_="body-table styled-table-new is-rounded p-0 mt-2")

    ###
    print("Insider Table: " + str(insider_table))

    parsed_data = []
   
    for row in insider_table.find_all("tr")[1:]:
        insider_name = row.find('td')
        # Get the Tradername in the first td element
        if insider_name is not None:
            insider_name = insider_name.text.strip()
        else:
            insider_name = None
        # Get the title of the Insider in the second td element
        insider_title = row.find_all('td')[1]
        if insider_title is not None:
            insider_title = insider_title.text.strip()
        else:
            insider_title = None
        # Get the date of the transaction in the third td element
        transaction_date = row.find_all('td')[2]
        if transaction_date is not None:
            transaction_date = transaction_date.text.strip()
        else:
            transaction_date = None
        # Get the type of transaction in the fourth td element
        transaction_type = row.find_all('td')[3]
        if transaction_type is not None:
            transaction_type = transaction_type.text.strip()
        else:
            transaction_type = None
        # Get the Cost of transaction in the fifth td element
        cost = row.find_all('td')[4]
        if cost is not None:
            cost = cost.text.strip()
        else:
            cost = None
        # Get the num of shares in the sixth td element
        num_shares = row.find_all('td')[5]
        if num_shares is not None:
            num_shares = num_shares.text.strip()
        else:
            num_shares = None
        # Get the Value of shares in the seventh td element
        value_shares = row.find_all('td')[6]
        if value_shares is not None:
            value_shares = value_shares.text.strip()
        else:
            value_shares = None
        # Get the num of shares the insider owns in the eighth td element
        total_num_shares_insider_owns = row.find_all('td')[7]
        if total_num_shares_insider_owns is not None:
            total_num_shares_insider_owns = total_num_shares_insider_owns.text.strip()
        else:
            total_num_shares_insider_owns = None
        # Get the date of the SEC Form, ka was das ist,  the ninth td element
        SEC_date = row.find_all('td')[7]
        if SEC_date is not None:
            SEC_date = SEC_date.text.strip()
        else:
            SEC_date = None

        parsed_data.append([insider_name, insider_title, transaction_date, transaction_type,
                            cost, num_shares, value_shares, total_num_shares_insider_owns, SEC_date])
    return parsed_data
    
def create_initial_df(path):

    list = crawl(url)
    df = pd.DataFrame(list, columns = ["insider" , "title", "transaction_date", "transaction_type",
                            "cost", "num_shares", "value_shares", "total_num_shares_insider_owns", "SEC_date"])
    #save df to local storage
    df.to_csv(path, index=False)

create_initial_df(path)
# Out:
# Response: <http.client.HTTPResponse object at 0x0000016B1B9BF790>
# Insider Table: <table cellpadding="0" cellspacing="0" class="body-table styled-table-new is-rounded p-0 mt-2" width="100%">
# <thead>
# <tr>
# <th align="left" class="">Insider Trading</th>
# <th align="left" class="">Relationship</th>
# <th align="left" class="">Date</th>
# <th align="center" class="">Transaction</th>
# <th align="right" class="">Cost</th>
# <th align="right" class="">#Shares</th>
# <th align="right" class="">Value ($)</th>
# <th align="right" class="">#Shares Total</th>
# <th align="center" class="">SEC Form 4</th>
# </tr>
# </thead>
# <tr class="fv-insider-row is-sale-1" valign="top"><td><a class="tab-link" href="insidertrading.ashx?oc=1684974&amp;tc=7">Selipsky Adam</a></td><td style="white-space:nowrap">CEO Amazon Web Services</td><td>Oct 06</td><td align="center" class="transaction" style="white-space:nowrap"><span>Sale</span></td><td align="right" class="value">124.13</td><td align="right" class="value">500</td><td align="right" class="value">62,065</td><td align="right" class="value">105,020</td><td align="center" class="whitespace-nowrap tabular-nums"><a class="tab-link" href="http://www.sec.gov/Archives/edgar/data/1018724/000110465923108355/xslF345X05/tm2327990-1_4seq1.xml" target="_blank">Oct 10 05:13 PM</a></td></tr><tr class="fv-insider-row is-sale-1" valign="top"><td><a class="tab-link" href="insidertrading.ashx?oc=1684974&amp;tc=7">Selipsky Adam</a></td><td style="white-space:nowrap">CEO Amazon Web Services</td><td>Oct 05</td><td align="center" class="transaction" style="white-space:nowrap"><span>Sale</span></td><td align="right" class="value">126.64</td><td align="right" class="value">500</td><td align="right" class="value">63,320</td><td align="right" class="value">105,520</td><td align="center" class="whitespace-nowrap tabular-nums"><a class="tab-link" href="http://www.sec.gov/Archives/edgar/data/1018724/000110465923108355/xslF345X05/tm2327990-1_4seq1.xml" target="_blank">Oct 10 05:13 PM</a></td></tr><tr class="fv-insider-row is-sale-2" valign="top"><td><a class="tab-link" href="insidertrading.ashx?oc=1936006&amp;tc=7">Herrington Douglas J</a></td><td style="white-space:nowrap">CEO Worldwide Amazon Stores</td><td>Oct 02</td><td align="center" class="transaction" style="white-space:nowrap"><span>Sale</span></td><td align="right" class="value">127.20</td><td align="right" class="value">4,000</td><td align="right" class="value">508,800</td><td align="right" class="value">522,316</td><td align="center" class="whitespace-nowrap tabular-nums"><a class="tab-link" href="http://www.sec.gov/Archives/edgar/data/1018724/000110465923106846/xslF345X05/tm2327446-1_4seq1.xml" target="_blank">Oct 04 04:33 PM</a></td></tr><tr class="fv-insider-row is-sale-1" valign="top"><td><a class="tab-link" href="insidertrading.ashx?oc=1684974&amp;tc=7">Selipsky Adam</a></td><td style="white-space:nowrap">CEO Amazon Web Services</td><td>Sep 21</td><td align="center" class="transaction" style="white-space:nowrap"><span>Sale</span></td><td align="right" class="value">131.80</td><td align="right" class="value">500</td><td align="right" class="value">65,900</td><td align="right" class="value">106,020</td><td align="center" class="whitespace-nowrap tabular-nums"><a class="tab-link" href="http://www.sec.gov/Archives/edgar/data/1018724/000110465923103217/xslF345X05/tm2326663-1_4seq1.xml" target="_blank">Sep 22 04:35 PM</a></td></tr><tr class="fv-insider-row is-sale-1" valign="top"><td><a class="tab-link" href="insidertrading.ashx?oc=1684974&amp;tc=7">Selipsky Adam</a></td><td style="white-space:nowrap">CEO Amazon Web Services</td><td>Sep 20</td><td align="center" class="transaction" style="white-space:nowrap"><span>Sale</span></td><td align="right" class="value">138.48</td><td align="right" class="value">500</td><td align="right" class="value">69,240</td><td align="right" class="value">106,520</td><td align="center" class="whitespace-nowrap tabular-nums"><a class="tab-link" href="http://www.sec.gov/Archives/edgar/data/1018724/000110465923103217/xslF345X05/tm2326663-1_4seq1.xml" target="_blank">Sep 22 04:35 PM</a></td></tr><tr class="fv-insider-row is-sale-2" valign="top"><td><a class="tab-link" href="insidertrading.ashx?oc=1557979&amp;tc=7">Zapolsky David</a></td><td style="white-space:nowrap">Senior Vice President</td><td>Sep 14</td><td align="center" class="transaction" style="white-space:nowrap"><span>Sale</span></td><td align="right" class="value">145.13</td><td align="right" class="value">42,816</td><td align="right" class="value">6,213,886</td><td align="right" class="value ...
